# %%
#Import Libraries
import requests
from requests import get
import pandas as pd
import json
import bs4

# %%
#Specify Zillow api key & Initialize list named Houses
apikey="X1-ZWz1irnrykh62z_4dboj"
houses= []

# %%
#Specify url link

import requests

url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

querystring = {"location":"Carolina,PR","page":"2","status_type":"ForRent","sort":"status_type=ForRent"}

headers = {
	"X-RapidAPI-Host": "zillow-com1.p.rapidapi.com",
	"X-RapidAPI-Key": "d90b6cbfd2msh4f358be332bacd5p1dbe43jsnafb103c6c029"
}

h = requests.request("GET", url, headers=headers, params=querystring)

def clean(text):
    if text:
        return ' '.join(' '.join(text).split())
    return None

print(h.text)
# Out:
# {"props":[{"dateSold":null,"propertyType":null,"lotAreaValue":null,"address":"9546 Calle Diaz Way Astralis Astralis, Carolina, PR","daysOnZillow":null,"price":null,"listingDateTime":null,"longitude":null,"latitude":null,"contingentListingType":null,"listingStatus":null,"zpid":"18.436432--66.01017","listingSubType":null,"imgSrc":"https:\/\/photos.zillowstatic.com\/fp\/d2b972f3a647cd4f292147b4e922d3ef-p_e.jpg","livingArea":null,"bathrooms":null,"lotAreaUnit":null,"country":null,"currency":null,"bedrooms":null,"hasImage":true},{"dateSold":null,"propertyType":"APARTMENT","lotAreaValue":null,"address":"(undisclosed Address), Carolina, PR 00979","daysOnZillow":-1,"price":2600,"listingDateTime":null,"longitude":null,"latitude":null,"contingentListingType":null,"listingStatus":"FOR_RENT","zpid":"2097122315","listingSubType":{},"imgSrc":"https:\/\/photos.zillowstatic.com\/fp\/194635af2601e5816610e07c4ba06599-p_e.jpg","livingArea":1000,"bathrooms":2,"lotAreaUnit":null,"country":"USA","currency
# ...

# %%
raw_json_data=print(h.json())
# Out:
# {'props': [{'dateSold': None, 'propertyType': None, 'lotAreaValue': None, 'address': '9546 Calle Diaz Way Astralis Astralis, Carolina, PR', 'daysOnZillow': None, 'price': None, 'listingDateTime': None, 'longitude': None, 'latitude': None, 'contingentListingType': None, 'listingStatus': None, 'zpid': '18.436432--66.01017', 'listingSubType': None, 'imgSrc': 'https://photos.zillowstatic.com/fp/d2b972f3a647cd4f292147b4e922d3ef-p_e.jpg', 'livingArea': None, 'bathrooms': None, 'lotAreaUnit': None, 'country': None, 'currency': None, 'bedrooms': None, 'hasImage': True}, {'dateSold': None, 'propertyType': 'APARTMENT', 'lotAreaValue': None, 'address': '(undisclosed Address), Carolina, PR 00979', 'daysOnZillow': -1, 'price': 2600, 'listingDateTime': None, 'longitude': None, 'latitude': None, 'contingentListingType': None, 'listingStatus': 'FOR_RENT', 'zpid': '2097122315', 'listingSubType': {}, 'imgSrc': 'https://photos.zillowstatic.com/fp/194635af2601e5816610e07c4ba06599-p_e.jpg', 'livingArea':
# ...

# %%
#Add data to houses list
houses.append(h.json())
houses
# Out:
# [{'props': [{'dateSold': None,
#     'propertyType': None,
#     'lotAreaValue': None,
#     'address': '9546 Calle Diaz Way Astralis Astralis, Carolina, PR',
#     'daysOnZillow': None,
#     'price': None,
#     'listingDateTime': None,
#     'longitude': None,
#     'latitude': None,
#     'contingentListingType': None,
#     'listingStatus': None,
#     'zpid': '18.436432--66.01017',
#     'listingSubType': None,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/d2b972f3a647cd4f292147b4e922d3ef-p_e.jpg',
#     'livingArea': None,
#     'bathrooms': None,
#     'lotAreaUnit': None,
#     'country': None,
#     'currency': None,
#     'bedrooms': None,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'APARTMENT',
#     'lotAreaValue': None,
#     'address': '(undisclosed Address), Carolina, PR 00979',
#     'daysOnZillow': -1,
#     'price': 2600,
#     'listingDateTime': None,
#     'longitude': None,
#     'latitude': None,
# ...

# %%
#Dataframe to Json string
puertorico_df=json.dumps(houses)
puertorico_df
# Out:
# '[{"props": [{"dateSold": null, "propertyType": null, "lotAreaValue": null, "address": "9546 Calle Diaz Way Astralis Astralis, Carolina, PR", "daysOnZillow": null, "price": null, "listingDateTime": null, "longitude": null, "latitude": null, "contingentListingType": null, "listingStatus": null, "zpid": "18.436432--66.01017", "listingSubType": null, "imgSrc": "https://photos.zillowstatic.com/fp/d2b972f3a647cd4f292147b4e922d3ef-p_e.jpg", "livingArea": null, "bathrooms": null, "lotAreaUnit": null, "country": null, "currency": null, "bedrooms": null, "hasImage": true}, {"dateSold": null, "propertyType": "APARTMENT", "lotAreaValue": null, "address": "(undisclosed Address), Carolina, PR 00979", "daysOnZillow": -1, "price": 2600, "listingDateTime": null, "longitude": null, "latitude": null, "contingentListingType": null, "listingStatus": "FOR_RENT", "zpid": "2097122315", "listingSubType": {}, "imgSrc": "https://photos.zillowstatic.com/fp/194635af2601e5816610e07c4ba06599-p_e.jpg", "livingArea
# ...

# %%
with open('Addlprhouses.json', 'w') as f:
    json.dump(houses, f, indent=2)
    print("New json file is created")
# Out:
# New json file is created

# %%
import csv
with open (prhouses.csv) as file:
    prhouses.csv=csv.writer(file)
    prhouses.writerow(["zpid","city"])
    for item in data ["prhouses.json"]:
        prhouses.writerow([])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19068/3006609146.py in <module>
#       1 import csv
# ----> 2 with open (prhouses.csv) as file:
#       3     prhouses.csv=csv.writer(file)
#       4     prhouses.writerow(["zpid","city"])
#       5     for item in data ["prhouses.json"]:
#
# NameError: name 'prhouses' is not defined

# %%
#String to json file
df = pd.read_json(puertorico_df)
df

# %%
#Convert Df to csv file
df.to_csv(index=False)

# %%
with open('"C:\Users\La'Cha\Documents\GWU Class Folder\Capstone Work\prhouses.json') as json_file:
    jsondata = puertorico_df(json_file)
 
data_file = open('G:\Akhil\jsonoutput.csv', 'w', newline="zpid": 2063382904")
csv_writer = csv.writer(data_file)

# %%
#Create PRhouses csv file from df 
import os
df.to_csv('prhouses.csv', columns=['Column_1','Column_2', sep = str('zpid\':'('\s+,)'), header = True, na_rep='Value Missing')

# %%
def get_data_from_json(h.json()):
    # getting data from json 

    cleaned_data = clean((h.json()).replace('<!--', "").replace("-->", "")
    
    properties_list = []

    try:
        json_data = json.loads(cleaned_data)
        search_results = json_data.get('searchResults').get('listResults', [])

        for properties in search_results:
            address = properties.get('addressWithZip')
            property_info = properties.get('hdpData', {}).get('homeInfo')
            city = property_info.get('city')
            state = property_info.get('state')
            postal_code = property_info.get('zipcode')
            price = properties.get('price')
            bedrooms = properties.get('beds')
            bathrooms = properties.get('baths')
            area = properties.get('area')
            info = f'{bedrooms} bds, {bathrooms} ba ,{area} sqft'
            broker = properties.get('brokerName')
            property_url = properties.get('detailUrl')
            title = properties.get('statusText')

            data = {'address': address,
                    'city': city,
                    'state': state,
                    'postal_code': postal_code,
                    'price': price,
                    'facts and features': info,
                    'real estate provider': broker,
                    'url': property_url,
                    'title': title}
            properties_list.append(data)

        return properties_list

    except ValueError:
        print("Invalid json")
        return None

# %%
properties_list

# %%
requests.get(
...     'https://api.github.com/search/repositories',
...     params=b'q=requests+language:python',
... )

# %%
print(dir(response))

# %%
print(help(response))

# %%
parsed=json.loads(response)
